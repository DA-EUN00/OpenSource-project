# %% [markdown]
# # Normal Distribution
# ## 정규분포

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
xs_2 = np.arange(-5, 5, 0.1)
plt.plot(xs_2, st.norm.pdf(xs_2, loc=0, scale=1))
plt.title('Normal Distribution')
plt.savefig('Normal_Distribution.png')
